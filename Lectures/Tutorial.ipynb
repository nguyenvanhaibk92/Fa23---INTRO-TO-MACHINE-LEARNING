# %% [markdown]
# # <h1><center> Tutorial </center></h1>
#
# ## <h1><center>TA: Hai Nguyen </center></h1>
#
# ---
#
# ## Today todo list:
#
# (feel free to stop and ask anytime)
#
# ### 1. what is google colab? [link to google colab](https://colab.research.google.com/?utm_source=scs-index)
# Aim: understand benefits of Google Colab.
#
# ### 2. load/save jupyter notebook with a google drive (you can do with Github, not covered in this tutorial)
# Aim: know how to rerun lecture notes + work with your homework
#
# ### 3. saving your homework jupyter notebook as pdf file.
# Aim: save your homework jupyter notebook as pdf file for submission to Canvas.
#
# ### 4. learning python / scikit-learn / other languages with chatGPT [Link to chartGPT](https://openai.com/blog/chatgpt)
# Aim: sharing personal tips/tricks.
#
# ### 5. Q&A section

# %% [markdown]
# ## Saving the jupyter notebook procedure

# %%
# !apt-get install texlive-xetex texlive-fonts-recommended texlive-generic-recommended
# !apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic
# !pip install nbconvert

# %%
# Importing your google driver
from google.colab import drive
drive.mount('/content/drive')

# Copy your file from your google drive to current main
# NTOE: "MyNotebook" should be changed your file name
# !cp drive/MyDrive/Colab_Notebooks/Fall23_tutorial/MyNotebook.ipynb .

# Convert to html (you can save pdf directly, but it looks bad)
# !jupyter nbconvert MyNotebook.ipynb --to html

# save html file to your local laptop
from google.colab import files
files.download('MyNotebook.html')

# Open your html file from the Download folder in you machine

# Save it as pdf
